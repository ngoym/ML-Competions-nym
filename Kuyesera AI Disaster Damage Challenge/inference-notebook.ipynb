# %% [markdown]
# ### Kuyesera AI Disaster Damage and Displacement Challenge
# * The goal of this notebook is to perform all the infeerence stages of our pipeline
# * The notebook assumes that you have read the readme provided and you understand the methodology we used
# * To make a brief recap, Our methodology follows a two stages approach
# * The two stages include object detection where we detect buildings from pre-images
# * Then use the predicted bounding boxes to create patches on both pre and post images
# * Then use this pair to perform damaage classification
# * We then can train a classifier for different classes. We found that training classifiers for `minor_damage` and `major_damage` were not accurate enough with AUC scores of ~0.8, and the vast distribution shift between xview2 and test data. We therefore only considered a classifier for the `destroyed` class which had an AUC score of ~0.93 in training. We used a Siamese neural network where the pre- and post-disaster images share the same weights.
# * Lastly based on this rule provided on the prizes section on the competition info page:
#     * "You must use at least one dataset from the Amazon Sustainability Data Initiative (ASDI) platform as part of your model." We used ndvi values provided by the ASDI platform in our classifier as we assumed that for us to be eligible for the prizes we must follow that rule.
#
# #### Objective
# * Since we have provided the diifferent weights and the generated datasets, This notebook makes use of that to run the whole inference pipeline
# * If you would like to perform the whole training process then please refer back to the readme to get the steps to do that

# %% [markdown]
# #### FIRST STAGE: OBJECT DETECTION
# * predict only one class : Building from the Malawi pre-disaster Images
# * Get the Bounding Boxes (predicted) and use them to crop both the pre-disaster images and post-dissaster image as we neeed the pair for classification
#
# NOTE: We ran this inference notebook on kaggle . If you would like to run it on colab make sure you change kaggle paths to colab. Training on the other hand you need a V100 gpu or any other equivalent (more info on the readme)

# %%
# !pip install ultralytics -q
# !pip install ensemble-boxes -q
# !pip install opencv-python -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 13.6 MB/s eta 0:00:00a 0:00:01

# %%
from ultralytics import YOLO, RTDETR
import os
import pdb
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import pickle
import sys
from ensemble_boxes import *

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
AUGMENT = True
RUN = 19 # 19
RUN2 = 19
loc = f'runs/detect/train{RUN}'
loc2 = f'runs/detect/train{RUN2}'
SZ = (928, 448)
SZ2 = (928, 448) # 928

THRESH = 0.5
IOU_THRESH = 0.2
CONF = 0.5 # 0.5
YOLO_IOU_THR = 0.35
EXT = 'png'

#using the same model for both paths
model_path = '/kaggle/input/kuyesera-final-submission/Final_sub/yolo_run19/train19/weights/best.pt'
model_path2 = '/kaggle/input/kuyesera-final-submission/Final_sub/yolo_run19/train19/weights/best.pt'
crops_dir = '/kaggle/working/crops'
os.makedirs(crops_dir, exist_ok=True)
test_dir  = "/kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images" #we generated the png equivalents of the provided tif images
tif_dir = "/kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images" #the test images from the zindi data tab
imgs = [os.path.join(test_dir, f) for f in os.listdir(test_dir) if f.endswith(f'_pre_disaster.{EXT}')]
imgs_post = [f.replace('_pre_disaster', '_post_disaster') for f in imgs]
tifs = [os.path.join(tif_dir, f) for f in os.listdir(tif_dir) if f.endswith(f'_pre_disaster.{EXT}')]

def get_areas(boxes):
    areas = []
    for b in boxes:
        arr = abs(b[2] - b[0]) * abs(b[3] - b[1])
        areas.append(arr)
    return areas

def get_results(res, threshold=0.5):
    res     = res.cpu().numpy()
    cls     = res.boxes.cls
    conf    = res.boxes.conf
    boxes   = res.boxes.xyxyn#.tolist()
    mask    = conf > threshold
    conf = conf[mask]
    cls = cls[mask]
    boxes = boxes[mask]

    return cls, boxes, conf

def run_nms(bboxes, confs,labels, image_size, iou_thr=0.50, skip_box_thr=0.0001, weights=None):
    boxes =  [bbox for bbox in bboxes]
    scores = [conf for conf in confs]
    #labels = [np.ones(conf.shape[0]) for conf in confs]
    boxes, scores, labels = nms(boxes, scores, labels, weights=weights, iou_thr=iou_thr)
    #boxes = boxes*(image_size-1)
    return boxes, scores, labels

def run_nmw(bboxes, confs,labels, image_size, iou_thr=0.50, skip_box_thr=0.0001, weights=None):
    boxes =  [bbox for bbox in bboxes]
    scores = [conf for conf in confs]
    #labels = [np.ones(conf.shape[0]) for conf in confs]
    boxes, scores, labels = non_maximum_weighted(boxes, scores, labels, weights=weights, iou_thr=iou_thr)
    #boxes = boxes*(image_size-1)
    return boxes, scores, labels

def run_soft_nms(bboxes, confs,labels, image_size, iou_thr=0.50, skip_box_thr=0.0001,sigma=0.1, weights=None):
    boxes =  [bbox for bbox in bboxes]
    scores = [conf for conf in confs]
    #labels = [np.ones(conf.shape[0]) for conf in confs]
    boxes, scores, labels = soft_nms(boxes, scores, labels, weights=weights, iou_thr=iou_thr, sigma=sigma, thresh=skip_box_thr)
    #boxes = boxes*(image_size-1)
    return boxes, scores, labels

def run_wbf(bboxes, confs,labels, image_size, iou_thr=0.50, skip_box_thr=0.0001, weights=None):
    #boxes =  [bbox/(image_size-1) for bbox in bboxes]
    boxes =  [bbox for bbox in bboxes]
    scores = [conf for conf in confs]
    #labels = [np.ones(conf.shape[0]) for conf in confs]
    boxes, scores, labels = weighted_boxes_fusion(boxes, scores, labels, weights=None, iou_thr=iou_thr, skip_box_thr=skip_box_thr)
    #boxes = boxes*(image_size-1)
    return boxes, scores, labels


idx = 0
print(imgs[idx])
print(imgs_post[idx])
model = YOLO(model_path)
model2 = YOLO(model_path2)
results = model(imgs[idx], imgsz=SZ, augment=AUGMENT, conf=CONF)
img = results[0].plot()
IM = Image.fromarray(img)
IM.save('yolo.jpg')

results = model(imgs_post[idx], imgsz=SZ, augment=AUGMENT, conf=CONF)
img = results[0].plot()
IM = Image.fromarray(img)
IM.save('yolo_post.jpg')

#sys.exit(0)
img_files = []
preds = []
rep_str = {
        1: "_X_no_damage",
        2: "_X_minor_damage",
        3: "_X_major_damage",
        4: "_X_destroyed",
    }
os.makedirs("crops", exist_ok=True)
data = {}
for im in imgs:
    print(".", end="", flush=True)
    id = os.path.basename(im).replace(f'_pre_disaster.{EXT}', '')
    data[id] = {'pre':[], 'post':[]}
    im2 = im.replace('_pre_disaster', '_post_disaster')
    img_pre = cv2.imread(im)
    img_post = cv2.imread(im2)
    results_pre = model(im, imgsz=SZ, augment=AUGMENT, conf=CONF, iou=YOLO_IOU_THR)
    results_pre2 = model2(im, imgsz=SZ2, augment=AUGMENT, conf=CONF, iou=YOLO_IOU_THR)
    #results_post = model(im2, imgsz=SZ, augment=AUGMENT, conf=0.5)
    #results_post2 = model2(im2, imgsz=SZ, augment=AUGMENT, conf=0.5)
    for res_pre, res_pre2 in zip(results_pre, results_pre2):
        ccls_pre, bbxs_pre, cnfs_pre = get_results(res_pre, threshold=THRESH)
        ccls_pre2, bbxs_pre2, cnfs_pre2 = get_results(res_pre2, threshold=THRESH)
        boxes_pre, scores_pre, labels_pre = run_wbf(
                                     [bbxs_pre, bbxs_pre2], [cnfs_pre, cnfs_pre2],
                                     [ccls_pre, ccls_pre2],
                                     SZ[0], iou_thr=IOU_THRESH)
        #boxes_pre, scores_pre, labels_pre = run_wbf(
        #                             [bbxs_pre], [cnfs_pre], [ccls_pre],
        #                             SZ[0], iou_thr=IOU_THRESH)
        boxes_pre[:,0] = boxes_pre[:,0] * res_pre.orig_shape[1]
        boxes_pre[:,1] = boxes_pre[:,1] * res_pre.orig_shape[0]
        boxes_pre[:,2] = boxes_pre[:,2] * res_pre.orig_shape[1]
        boxes_pre[:,3] = boxes_pre[:,3] * res_pre.orig_shape[0]
        for i in range(len(boxes_pre)):
            x1,y1,x2,y2 = boxes_pre[i]
            crop_pre = img_pre[int(y1):int(y2), int(x1):int(x2)]
            crop_post = img_post[int(y1):int(y2), int(x1):int(x2)]
            if crop_pre.shape[0] != crop_post.shape[0]:
                height = min(crop_pre.shape[0], crop_post.shape[0])
                crop_pre = cv2.resize(crop_pre, (crop_pre.shape[1], height))
                crop_post = cv2.resize(crop_post, (crop_post.shape[1], height))
            # Stitch images side by side
            #stitched_image = np.hstack((crop_pre, crop_post))
            #cv2.imwrite(f"crops/{id}_X_{i}.jpg", stitched_image)
            #data[id]['pre'].append(f"{id}_X_{i}.jpg")
            cv2.imwrite(f"/kaggle/working/crops/{id}_X_{i}_pre.jpg", crop_pre)
            cv2.imwrite(f"/kaggle/working/crops/{id}_X_{i}_post.jpg", crop_post)
            data[id]['pre'].append(f"{id}_X_{i}_pre.jpg")
            data[id]['post'].append(f"{id}_X_{i}_post.jpg")

with open('/kaggle/working/data.pkl', 'wb') as f:
    pickle.dump(data, f)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_pre_disaster.png
# /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_post_disaster.png
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_pre_disaster.png: 224x448 66 buildings, 290.9ms
# Speed: 11.5ms preprocess, 290.9ms inference, 275.6ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_post_disaster.png: 224x448 60 buildings, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_pre_disaster.png: 224x448 63 buildings, 57.4ms
# Speed: 0.9ms preprocess, 57.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000084_pre_disaster.png: 224x448 63 buildings, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000241_pre_disaster.png: 224x448 169 buildings, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000241_pre_disaster.png: 224x448 169 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000339_pre_disaster.png: 224x448 15 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000339_pre_disaster.png: 224x448 15 buildings, 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000071_pre_disaster.png: 224x448 82 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000071_pre_disaster.png: 224x448 82 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000254_pre_disaster.png: 224x448 157 buildings, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000254_pre_disaster.png: 224x448 157 buildings, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000135_pre_disaster.png: 192x448 14 buildings, 116.7ms
# Speed: 1.0ms preprocess, 116.7ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000135_pre_disaster.png: 192x448 14 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000259_pre_disaster.png: 224x448 18 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000259_pre_disaster.png: 224x448 18 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000082_pre_disaster.png: 224x448 74 buildings, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000082_pre_disaster.png: 224x448 74 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000155_pre_disaster.png: 224x448 23 buildings, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000155_pre_disaster.png: 224x448 23 buildings, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000208_pre_disaster.png: 224x448 43 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000208_pre_disaster.png: 224x448 43 buildings, 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000026_pre_disaster.png: 224x448 45 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000026_pre_disaster.png: 224x448 45 buildings, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000023_pre_disaster.png: 224x448 55 buildings, 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000023_pre_disaster.png: 224x448 55 buildings, 50.3ms
# Speed: 0.9ms preprocess, 50.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000287_pre_disaster.png: 224x448 6 buildings, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000287_pre_disaster.png: 224x448 6 buildings, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000263_pre_disaster.png: 224x448 3 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000263_pre_disaster.png: 224x448 3 buildings, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000069_pre_disaster.png: 224x448 12 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000069_pre_disaster.png: 224x448 12 buildings, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000294_pre_disaster.png: 224x448 5 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000294_pre_disaster.png: 224x448 5 buildings, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000327_pre_disaster.png: 224x448 48 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000327_pre_disaster.png: 224x448 48 buildings, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000024_pre_disaster.png: 224x448 44 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000024_pre_disaster.png: 224x448 44 buildings, 50.7ms
# Speed: 0.9ms preprocess, 50.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000178_pre_disaster.png: 224x448 18 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000178_pre_disaster.png: 224x448 18 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000196_pre_disaster.png: 224x448 16 buildings, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000196_pre_disaster.png: 224x448 16 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000031_pre_disaster.png: 224x448 27 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000031_pre_disaster.png: 224x448 27 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000068_pre_disaster.png: 224x448 5 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000068_pre_disaster.png: 224x448 5 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000079_pre_disaster.png: 224x448 59 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000079_pre_disaster.png: 224x448 59 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000228_pre_disaster.png: 224x448 74 buildings, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000228_pre_disaster.png: 224x448 74 buildings, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000219_pre_disaster.png: 224x448 36 buildings, 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000219_pre_disaster.png: 224x448 36 buildings, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000318_pre_disaster.png: 224x448 58 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000318_pre_disaster.png: 224x448 58 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000201_pre_disaster.png: 224x448 34 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000201_pre_disaster.png: 224x448 34 buildings, 52.4ms
# Speed: 0.9ms preprocess, 52.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000341_pre_disaster.png: 224x448 52 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000341_pre_disaster.png: 224x448 52 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000060_pre_disaster.png: 224x448 62 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000060_pre_disaster.png: 224x448 62 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000172_pre_disaster.png: 224x448 31 buildings, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000172_pre_disaster.png: 224x448 31 buildings, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000194_pre_disaster.png: 224x448 40 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000194_pre_disaster.png: 224x448 40 buildings, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000104_pre_disaster.png: 224x448 13 buildings, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000104_pre_disaster.png: 224x448 13 buildings, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000129_pre_disaster.png: 224x448 19 buildings, 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000129_pre_disaster.png: 224x448 19 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000122_pre_disaster.png: 224x448 13 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000122_pre_disaster.png: 224x448 13 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000247_pre_disaster.png: 224x448 1 building, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000247_pre_disaster.png: 224x448 1 building, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000054_pre_disaster.png: 224x448 61 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000054_pre_disaster.png: 224x448 61 buildings, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000125_pre_disaster.png: 224x448 20 buildings, 51.5ms
# Speed: 1.1ms preprocess, 51.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000125_pre_disaster.png: 224x448 20 buildings, 52.8ms
# Speed: 0.9ms preprocess, 52.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000037_pre_disaster.png: 224x448 40 buildings, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000037_pre_disaster.png: 224x448 40 buildings, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000346_pre_disaster.png: 224x448 36 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000346_pre_disaster.png: 224x448 36 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000250_pre_disaster.png: 224x448 10 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000250_pre_disaster.png: 224x448 10 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000190_pre_disaster.png: 224x448 66 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000190_pre_disaster.png: 224x448 66 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000038_pre_disaster.png: 224x448 40 buildings, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000038_pre_disaster.png: 224x448 40 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000142_pre_disaster.png: 224x448 46 buildings, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000142_pre_disaster.png: 224x448 46 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000085_pre_disaster.png: 224x448 84 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000085_pre_disaster.png: 224x448 84 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000051_pre_disaster.png: 224x448 39 buildings, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000051_pre_disaster.png: 224x448 39 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000292_pre_disaster.png: 224x448 4 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000292_pre_disaster.png: 224x448 4 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000264_pre_disaster.png: 224x448 9 buildings, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000264_pre_disaster.png: 224x448 9 buildings, 51.4ms
# Speed: 0.9ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000052_pre_disaster.png: 224x448 49 buildings, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000052_pre_disaster.png: 224x448 49 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000234_pre_disaster.png: 224x448 18 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000234_pre_disaster.png: 224x448 18 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000286_pre_disaster.png: 224x448 49 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000286_pre_disaster.png: 224x448 49 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000268_pre_disaster.png: 224x448 (no detections), 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000268_pre_disaster.png: 224x448 (no detections), 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000311_pre_disaster.png: 224x448 32 buildings, 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000311_pre_disaster.png: 224x448 32 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000272_pre_disaster.png: 224x448 12 buildings, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000272_pre_disaster.png: 224x448 12 buildings, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000296_pre_disaster.png: 224x448 9 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000296_pre_disaster.png: 224x448 9 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000141_pre_disaster.png: 224x448 66 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000141_pre_disaster.png: 224x448 66 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000317_pre_disaster.png: 224x448 60 buildings, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000317_pre_disaster.png: 224x448 60 buildings, 55.9ms
# Speed: 0.9ms preprocess, 55.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000269_pre_disaster.png: 224x448 4 buildings, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000269_pre_disaster.png: 224x448 4 buildings, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000083_pre_disaster.png: 224x448 72 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000083_pre_disaster.png: 224x448 72 buildings, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000334_pre_disaster.png: 224x448 40 buildings, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000334_pre_disaster.png: 224x448 40 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000216_pre_disaster.png: 224x448 20 buildings, 58.6ms
# Speed: 1.0ms preprocess, 58.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000216_pre_disaster.png: 224x448 20 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000138_pre_disaster.png: 224x448 3 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000138_pre_disaster.png: 224x448 3 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000090_pre_disaster.png: 224x448 47 buildings, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000090_pre_disaster.png: 224x448 47 buildings, 50.7ms
# Speed: 0.9ms preprocess, 50.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000042_pre_disaster.png: 224x448 27 buildings, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000042_pre_disaster.png: 224x448 27 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000310_pre_disaster.png: 224x448 20 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000310_pre_disaster.png: 224x448 20 buildings, 50.3ms
# Speed: 0.9ms preprocess, 50.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000195_pre_disaster.png: 224x448 35 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000195_pre_disaster.png: 224x448 35 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000226_pre_disaster.png: 224x448 94 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000226_pre_disaster.png: 224x448 94 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000238_pre_disaster.png: 224x448 28 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000238_pre_disaster.png: 224x448 28 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000123_pre_disaster.png: 224x448 14 buildings, 50.0ms
# Speed: 1.1ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000123_pre_disaster.png: 224x448 14 buildings, 51.0ms
# Speed: 0.9ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000041_pre_disaster.png: 224x448 46 buildings, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000041_pre_disaster.png: 224x448 46 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000306_pre_disaster.png: 224x448 43 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000306_pre_disaster.png: 224x448 43 buildings, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000011_pre_disaster.png: 224x448 33 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000011_pre_disaster.png: 224x448 33 buildings, 51.7ms
# Speed: 0.9ms preprocess, 51.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000078_pre_disaster.png: 224x448 39 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000078_pre_disaster.png: 224x448 39 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000115_pre_disaster.png: 224x448 37 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000115_pre_disaster.png: 224x448 37 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000167_pre_disaster.png: 224x448 36 buildings, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000167_pre_disaster.png: 224x448 36 buildings, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000111_pre_disaster.png: 224x448 44 buildings, 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000111_pre_disaster.png: 224x448 44 buildings, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000160_pre_disaster.png: 224x448 (no detections), 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000160_pre_disaster.png: 224x448 (no detections), 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000019_pre_disaster.png: 224x448 28 buildings, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000019_pre_disaster.png: 224x448 28 buildings, 55.9ms
# Speed: 0.9ms preprocess, 55.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000243_pre_disaster.png: 224x448 52 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000243_pre_disaster.png: 224x448 52 buildings, 51.2ms
# Speed: 0.9ms preprocess, 51.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000180_pre_disaster.png: 224x448 39 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000180_pre_disaster.png: 224x448 39 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000096_pre_disaster.png: 224x448 51 buildings, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000096_pre_disaster.png: 224x448 51 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000214_pre_disaster.png: 224x448 72 buildings, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000214_pre_disaster.png: 224x448 72 buildings, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000200_pre_disaster.png: 224x448 47 buildings, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000200_pre_disaster.png: 224x448 47 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000179_pre_disaster.png: 224x448 44 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000179_pre_disaster.png: 224x448 44 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000137_pre_disaster.png: 192x448 10 buildings, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000137_pre_disaster.png: 192x448 10 buildings, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000009_pre_disaster.png: 224x448 23 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000009_pre_disaster.png: 224x448 23 buildings, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000144_pre_disaster.png: 224x448 30 buildings, 50.4ms
# Speed: 0.9ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000144_pre_disaster.png: 224x448 30 buildings, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000047_pre_disaster.png: 224x448 44 buildings, 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000047_pre_disaster.png: 224x448 44 buildings, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000183_pre_disaster.png: 224x448 43 buildings, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000183_pre_disaster.png: 224x448 43 buildings, 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000058_pre_disaster.png: 224x448 72 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000058_pre_disaster.png: 224x448 72 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000072_pre_disaster.png: 224x448 21 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000072_pre_disaster.png: 224x448 21 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000177_pre_disaster.png: 224x448 27 buildings, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000177_pre_disaster.png: 224x448 27 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000136_pre_disaster.png: 192x448 17 buildings, 50.8ms
# Speed: 0.9ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000136_pre_disaster.png: 192x448 17 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000036_pre_disaster.png: 224x448 72 buildings, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000036_pre_disaster.png: 224x448 72 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000244_pre_disaster.png: 224x448 26 buildings, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000244_pre_disaster.png: 224x448 26 buildings, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000145_pre_disaster.png: 224x448 31 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# ...
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000014_pre_disaster.png: 224x448 66 buildings, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000014_pre_disaster.png: 224x448 66 buildings, 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000213_pre_disaster.png: 224x448 95 buildings, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000213_pre_disaster.png: 224x448 95 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000293_pre_disaster.png: 224x448 (no detections), 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000293_pre_disaster.png: 224x448 (no detections), 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000229_pre_disaster.png: 224x448 39 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000229_pre_disaster.png: 224x448 39 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000207_pre_disaster.png: 224x448 20 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000207_pre_disaster.png: 224x448 20 buildings, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000046_pre_disaster.png: 224x448 63 buildings, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000046_pre_disaster.png: 224x448 63 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000225_pre_disaster.png: 224x448 105 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000225_pre_disaster.png: 224x448 105 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000283_pre_disaster.png: 224x448 21 buildings, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000283_pre_disaster.png: 224x448 21 buildings, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000315_pre_disaster.png: 224x448 6 buildings, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000315_pre_disaster.png: 224x448 6 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000003_pre_disaster.png: 224x448 11 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000003_pre_disaster.png: 224x448 11 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000221_pre_disaster.png: 224x448 53 buildings, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000221_pre_disaster.png: 224x448 53 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000013_pre_disaster.png: 224x448 54 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000013_pre_disaster.png: 224x448 54 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000114_pre_disaster.png: 224x448 16 buildings, 54.3ms
# Speed: 1.0ms preprocess, 54.3ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000114_pre_disaster.png: 224x448 16 buildings, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000156_pre_disaster.png: 224x448 30 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000156_pre_disaster.png: 224x448 30 buildings, 52.8ms
# Speed: 0.9ms preprocess, 52.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000265_pre_disaster.png: 224x448 15 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000265_pre_disaster.png: 224x448 15 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000285_pre_disaster.png: 224x448 26 buildings, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000285_pre_disaster.png: 224x448 26 buildings, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000275_pre_disaster.png: 224x448 66 buildings, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000275_pre_disaster.png: 224x448 66 buildings, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000173_pre_disaster.png: 224x448 4 buildings, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000173_pre_disaster.png: 224x448 4 buildings, 51.6ms
# Speed: 0.9ms preprocess, 51.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000040_pre_disaster.png: 224x448 58 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000040_pre_disaster.png: 224x448 58 buildings, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000313_pre_disaster.png: 224x448 6 buildings, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000313_pre_disaster.png: 224x448 6 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000134_pre_disaster.png: 224x448 25 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000134_pre_disaster.png: 224x448 25 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000126_pre_disaster.png: 224x448 27 buildings, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000126_pre_disaster.png: 224x448 27 buildings, 50.3ms
# Speed: 0.9ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000236_pre_disaster.png: 224x448 27 buildings, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000236_pre_disaster.png: 224x448 27 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000128_pre_disaster.png: 224x448 10 buildings, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000128_pre_disaster.png: 224x448 10 buildings, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000170_pre_disaster.png: 224x448 33 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000170_pre_disaster.png: 224x448 33 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000086_pre_disaster.png: 224x448 64 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000086_pre_disaster.png: 224x448 64 buildings, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000338_pre_disaster.png: 224x448 4 buildings, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000338_pre_disaster.png: 224x448 4 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000210_pre_disaster.png: 224x448 57 buildings, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000210_pre_disaster.png: 224x448 57 buildings, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000299_pre_disaster.png: 224x448 83 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000299_pre_disaster.png: 224x448 83 buildings, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000032_pre_disaster.png: 224x448 47 buildings, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000032_pre_disaster.png: 224x448 47 buildings, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000074_pre_disaster.png: 224x448 50 buildings, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000074_pre_disaster.png: 224x448 50 buildings, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
# .
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000030_pre_disaster.png: 224x448 26 buildings, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)
#
# image 1/1 /kaggle/input/kuyesera-final-submission/Final_sub/test_images/Images/malawi-cyclone_00000030_pre_disaster.png: 224x448 26 buildings, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 448)

# %% [markdown]
# ### SECOND STAGE: PAIR CLASSIFICATION
# * With the image pair from the previous stage and the ndvi values from the ASDI platform(to see how we generated the NDVI values look at the gen_data.py script provided) we now classify the type of damage present.
# * Just as explained above, We then can train a classifier for different classes. We found that training classifiers for minor_damage and major_damage were not accurate enough with AUC scores of ~0.8, and the vast distribution shift between xview2 and test data. We therefore only considered a classifier for the destroyed class which had an AUC score of ~0.93 in training. We used a Siamese neural network where the pre- and post-disaster images share the same weights.

# %%
import os
import cv2
import pickle
from timm import create_model
import pdb
import torch
import torch.nn as nn
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import pandas as pd

SZ = 128
FOLD = 0
MODEL = 'efficientvit_b0.r224_in1k'

DATA_DIR = "/kaggle/working/"
CROPS_DIR = "crops" # "mmde_crops" for mmdet, "crops" for yolo
disaster_dir = os.path.join(DATA_DIR, CROPS_DIR)
DATA_FILE = "/kaggle/working/data.pkl" # "mmdet_data.pkl" for mmdet, data.pkl for yolo
with open(DATA_FILE, "rb") as f:
    data = pickle.load(f)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
test_df = pd.read_csv("/kaggle/input/kuyesera-final-submission/Final_sub/test_ndvi.csv")

class DisasterClassifier(nn.Module):
    def __init__(self):
        super(DisasterClassifier, self).__init__()
        self.features = create_model(MODEL, pretrained=True, num_classes=0)

        self.fc = nn.Linear(1+1, 1)

    def euclidean_distance(self, x1, x2):
        return torch.sqrt(torch.sum((x1 - x2)**2, dim=1, keepdim=True))

    def forward(self, pre_image, post_image, x):
        # Extract features from both images
        pre_features = self.features(pre_image)
        post_features = self.features(post_image)

        distance = self.euclidean_distance(pre_features, post_features)
        distance = torch.cat([distance, x], dim=1)
        out = torch.sigmoid(self.fc(distance))
        return out

valid_transform = A.Compose([
    A.Resize(SZ, SZ),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
], additional_targets={'image2': 'image'})


model = DisasterClassifier()
model.load_state_dict(torch.load("/kaggle/input/kuyesera-final-submission/Final_sub/efficientvit_b0.r224_in1k_3_patch_model_fold_0.pth"))
model = model.to(device)
model.eval()
ids = []
damage = []
d_count = 0
for i in data.keys():
    print("[INFO] - Processing", i, flush=True)
    d = {
        0: {'id':f"{i}_X_no_damage", 'count':0},
        1: {'id':f"{i}_X_minor_damage", 'count':0},
        2: {'id':f"{i}_X_major_damage", 'count':0},
        3: {'id':f"{i}_X_destroyed", 'count':0}
    }
    nvdi = torch.tensor(test_df[test_df['id'] == i]['NDVI_mean'].values[0], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    for j in data[i]['pre']:
        pre_image = cv2.imread(os.path.join(disaster_dir, j))
        post_image = cv2.imread(os.path.join(disaster_dir, j.replace("_pre.jpg", "_post.jpg")))
        pre_size = os.path.getsize(os.path.join(disaster_dir, j))
        post_size = os.path.getsize(os.path.join(disaster_dir, j.replace("_pre.jpg", "_post.jpg")))

        #if pre_size < 1024*2 or post_size < 1024*2:
            #if pre_size/post_size >= 2 or post_size < pre_size:
            #    d[3]['count'] += 1
            #elif post_size > pre_size:
            #    d[0]['count'] += 1
        #    continue

        pre_image = cv2.cvtColor(pre_image, cv2.COLOR_BGR2RGB)
        post_image = cv2.cvtColor(post_image, cv2.COLOR_BGR2RGB)
        pre_image = valid_transform(image=pre_image)['image']
        post_image = valid_transform(image=post_image)['image']
        pre_image_ = pre_image.unsqueeze(0).to(device)
        post_image_ = post_image.unsqueeze(0).to(device)
        with torch.no_grad():
            out = model(pre_image_, post_image_, nvdi)
        if out.item() > 0.5:
            d[3]['count'] += 1
            d_count += 1
            pdb.set_trace()
            #cv2.imwrite("abs_pre_image.png", pre_image.permute(1,2,0).cpu().numpy())
            #cv2.imwrite("abs_post_image.png", post_image.permute(1,2,0).cpu().numpy())
            #db.set_trace()
        else:
            d[0]['count'] += 1

    for k in d.keys():
        ids.append(d[k]['id'])
        damage.append(d[k]['count'])

submission = pd.DataFrame({'id':ids, 'damage':damage})
submission.to_csv(f"cls_{MODEL}_submission.csv", index=False)
print("[INFO] - Num destroyed", d_count, flush=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.2 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# model.safetensors:   0%|          | 0.00/13.7M [00:00<?, ?B/s]
# [INFO] - Processing malawi-cyclone_00000084
# [INFO] - Processing malawi-cyclone_00000241
# [INFO] - Processing malawi-cyclone_00000339
# [INFO] - Processing malawi-cyclone_00000071
# [INFO] - Processing malawi-cyclone_00000254
# [INFO] - Processing malawi-cyclone_00000135
# [INFO] - Processing malawi-cyclone_00000259
# [INFO] - Processing malawi-cyclone_00000082
# [INFO] - Processing malawi-cyclone_00000155
# [INFO] - Processing malawi-cyclone_00000208
# [INFO] - Processing malawi-cyclone_00000026
# [INFO] - Processing malawi-cyclone_00000023
# [INFO] - Processing malawi-cyclone_00000287
# [INFO] - Processing malawi-cyclone_00000263
# [INFO] - Processing malawi-cyclone_00000069
# [INFO] - Processing malawi-cyclone_00000294
# [INFO] - Processing malawi-cyclone_00000327
# [INFO] - Processing malawi-cyclone_00000024
# [INFO] - Processing malawi-cyclone_00000178
# [INFO] - Processing malawi-cyclone_00000196
# [INFO] - Processing malawi-cyclone_00000031
# [INFO] - Processing malawi-cyclone_00000068
# [INFO] - Processing malawi-cyclone_00000079
# [INFO] - Processing malawi-cyclone_00000228
# [INFO] - Processing malawi-cyclone_00000219
# [INFO] - Processing malawi-cyclone_00000318
# [INFO] - Processing malawi-cyclone_00000201
# [INFO] - Processing malawi-cyclone_00000341
# [INFO] - Processing malawi-cyclone_00000060
# [INFO] - Processing malawi-cyclone_00000172
# [INFO] - Processing malawi-cyclone_00000194
# [INFO] - Processing malawi-cyclone_00000104
# [INFO] - Processing malawi-cyclone_00000129
# [INFO] - Processing malawi-cyclone_00000122
# [INFO] - Processing malawi-cyclone_00000247
# [INFO] - Processing malawi-cyclone_00000054
# [INFO] - Processing malawi-cyclone_00000125
# [INFO] - Processing malawi-cyclone_00000037
# [INFO] - Processing malawi-cyclone_00000346
# [INFO] - Processing malawi-cyclone_00000250
# [INFO] - Processing malawi-cyclone_00000190
# [INFO] - Processing malawi-cyclone_00000038
# [INFO] - Processing malawi-cyclone_00000142
# [INFO] - Processing malawi-cyclone_00000085
# [INFO] - Processing malawi-cyclone_00000051
# [INFO] - Processing malawi-cyclone_00000292
# [INFO] - Processing malawi-cyclone_00000264
# [INFO] - Processing malawi-cyclone_00000052
# [INFO] - Processing malawi-cyclone_00000234
# [INFO] - Processing malawi-cyclone_00000286
# [INFO] - Processing malawi-cyclone_00000268
# [INFO] - Processing malawi-cyclone_00000311
# [INFO] - Processing malawi-cyclone_00000272
# [INFO] - Processing malawi-cyclone_00000296
# [INFO] - Processing malawi-cyclone_00000141
# [INFO] - Processing malawi-cyclone_00000317
# [INFO] - Processing malawi-cyclone_00000269
# [INFO] - Processing malawi-cyclone_00000083
# [INFO] - Processing malawi-cyclone_00000334
# [INFO] - Processing malawi-cyclone_00000216
# [INFO] - Processing malawi-cyclone_00000138
# [INFO] - Processing malawi-cyclone_00000090
# [INFO] - Processing malawi-cyclone_00000042
# [INFO] - Processing malawi-cyclone_00000310
# [INFO] - Processing malawi-cyclone_00000195
# [INFO] - Processing malawi-cyclone_00000226
# [INFO] - Processing malawi-cyclone_00000238
# [INFO] - Processing malawi-cyclone_00000123
# [INFO] - Processing malawi-cyclone_00000041
# [INFO] - Processing malawi-cyclone_00000306
# [INFO] - Processing malawi-cyclone_00000011
# [INFO] - Processing malawi-cyclone_00000078
# [INFO] - Processing malawi-cyclone_00000115
# [INFO] - Processing malawi-cyclone_00000167
# [INFO] - Processing malawi-cyclone_00000111
# [INFO] - Processing malawi-cyclone_00000160
# [INFO] - Processing malawi-cyclone_00000019
# [INFO] - Processing malawi-cyclone_00000243
# [INFO] - Processing malawi-cyclone_00000180
# [INFO] - Processing malawi-cyclone_00000096
# [INFO] - Processing malawi-cyclone_00000214
# [INFO] - Processing malawi-cyclone_00000200
# [INFO] - Processing malawi-cyclone_00000179
# [INFO] - Processing malawi-cyclone_00000137
# [INFO] - Processing malawi-cyclone_00000009
# [INFO] - Processing malawi-cyclone_00000144
# [INFO] - Processing malawi-cyclone_00000047
# [INFO] - Processing malawi-cyclone_00000183
# [INFO] - Processing malawi-cyclone_00000058
# [INFO] - Processing malawi-cyclone_00000072
# [INFO] - Processing malawi-cyclone_00000177
# [INFO] - Processing malawi-cyclone_00000136
# [INFO] - Processing malawi-cyclone_00000036
# [INFO] - Processing malawi-cyclone_00000244
# [INFO] - Processing malawi-cyclone_00000145
# [INFO] - Processing malawi-cyclone_00000199
# [INFO] - Processing malawi-cyclone_00000099
# [INFO] - Processing malawi-cyclone_00000314
# [INFO] - Processing malawi-cyclone_00000025
# [INFO] - Processing malawi-cyclone_00000343
# [INFO] - Processing malawi-cyclone_00000103
# [INFO] - Processing malawi-cyclone_00000239
# [INFO] - Processing malawi-cyclone_00000073
# [INFO] - Processing malawi-cyclone_00000166
# [INFO] - Processing malawi-cyclone_00000088
# [INFO] - Processing malawi-cyclone_00000027
# [INFO] - Processing malawi-cyclone_00000108
# [INFO] - Processing malawi-cyclone_00000006
# [INFO] - Processing malawi-cyclone_00000319
# [INFO] - Processing malawi-cyclone_00000153
# [INFO] - Processing malawi-cyclone_00000186
# [INFO] - Processing malawi-cyclone_00000150
# [INFO] - Processing malawi-cyclone_00000271
# [INFO] - Processing malawi-cyclone_00000316
# [INFO] - Processing malawi-cyclone_00000320
# [INFO] - Processing malawi-cyclone_00000332
# [INFO] - Processing malawi-cyclone_00000303
# [INFO] - Processing malawi-cyclone_00000113
# [INFO] - Processing malawi-cyclone_00000076
# [INFO] - Processing malawi-cyclone_00000056
# [INFO] - Processing malawi-cyclone_00000063
# [INFO] - Processing malawi-cyclone_00000345
# [INFO] - Processing malawi-cyclone_00000033
# [INFO] - Processing malawi-cyclone_00000158
# [INFO] - Processing malawi-cyclone_00000188
# [INFO] - Processing malawi-cyclone_00000322
# [INFO] - Processing malawi-cyclone_00000202
# [INFO] - Processing malawi-cyclone_00000067
# [INFO] - Processing malawi-cyclone_00000206
# [INFO] - Processing malawi-cyclone_00000298
# [INFO] - Processing malawi-cyclone_00000240
# [INFO] - Processing malawi-cyclone_00000095
# [INFO] - Processing malawi-cyclone_00000230
# [INFO] - Processing malawi-cyclone_00000335
# [INFO] - Processing malawi-cyclone_00000159
# [INFO] - Processing malawi-cyclone_00000062
# [INFO] - Processing malawi-cyclone_00000290
# [INFO] - Processing malawi-cyclone_00000337
# [INFO] - Processing malawi-cyclone_00000192
# [INFO] - Processing malawi-cyclone_00000061
# [INFO] - Processing malawi-cyclone_00000018
# [INFO] - Processing malawi-cyclone_00000091
# [INFO] - Processing malawi-cyclone_00000176
# [INFO] - Processing malawi-cyclone_00000077
# [INFO] - Processing malawi-cyclone_00000252
# [INFO] - Processing malawi-cyclone_00000324
# [INFO] - Processing malawi-cyclone_00000248
# [INFO] - Processing malawi-cyclone_00000211
# [INFO] - Processing malawi-cyclone_00000284
# [INFO] - Processing malawi-cyclone_00000118
# [INFO] - Processing malawi-cyclone_00000185
# [INFO] - Processing malawi-cyclone_00000222
# [INFO] - Processing malawi-cyclone_00000101
# [INFO] - Processing malawi-cyclone_00000203
# [INFO] - Processing malawi-cyclone_00000105
# [INFO] - Processing malawi-cyclone_00000034
# [INFO] - Processing malawi-cyclone_00000043
# [INFO] - Processing malawi-cyclone_00000140
# [INFO] - Processing malawi-cyclone_00000307
# [INFO] - Processing malawi-cyclone_00000340
# [INFO] - Processing malawi-cyclone_00000028
# [INFO] - Processing malawi-cyclone_00000261
# [INFO] - Processing malawi-cyclone_00000107
# [INFO] - Processing malawi-cyclone_00000227
# [INFO] - Processing malawi-cyclone_00000328
# [INFO] - Processing malawi-cyclone_00000048
# [INFO] - Processing malawi-cyclone_00000223
# [INFO] - Processing malawi-cyclone_00000120
# [INFO] - Processing malawi-cyclone_00000117
# [INFO] - Processing malawi-cyclone_00000304
# [INFO] - Processing malawi-cyclone_00000282
# [INFO] - Processing malawi-cyclone_00000157
# [INFO] - Processing malawi-cyclone_00000087
# [INFO] - Processing malawi-cyclone_00000212
# [INFO] - Processing malawi-cyclone_00000329
# [INFO] - Processing malawi-cyclone_00000109
# [INFO] - Processing malawi-cyclone_00000092
# [INFO] - Processing malawi-cyclone_00000016
# [INFO] - Processing malawi-cyclone_00000279
# [INFO] - Processing malawi-cyclone_00000151
# [INFO] - Processing malawi-cyclone_00000017
# [INFO] - Processing malawi-cyclone_00000246
# [INFO] - Processing malawi-cyclone_00000080
# [INFO] - Processing malawi-cyclone_00000251
# [INFO] - Processing malawi-cyclone_00000255
# [INFO] - Processing malawi-cyclone_00000281
# [INFO] - Processing malawi-cyclone_00000149
# [INFO] - Processing malawi-cyclone_00000347
# [INFO] - Processing malawi-cyclone_00000110
# [INFO] - Processing malawi-cyclone_00000002
# [INFO] - Processing malawi-cyclone_00000100
# [INFO] - Processing malawi-cyclone_00000022
# [INFO] - Processing malawi-cyclone_00000020
# [INFO] - Processing malawi-cyclone_00000325
# [INFO] - Processing malawi-cyclone_00000116
# [INFO] - Processing malawi-cyclone_00000204
# [INFO] - Processing malawi-cyclone_00000321
# [INFO] - Processing malawi-cyclone_00000235
# [INFO] - Processing malawi-cyclone_00000175
# [INFO] - Processing malawi-cyclone_00000055
# [INFO] - Processing malawi-cyclone_00000257
# [INFO] - Processing malawi-cyclone_00000258
# [INFO] - Processing malawi-cyclone_00000098
# [INFO] - Processing malawi-cyclone_00000168
# [INFO] - Processing malawi-cyclone_00000059
# [INFO] - Processing malawi-cyclone_00000224
# [INFO] - Processing malawi-cyclone_00000193
# [INFO] - Processing malawi-cyclone_00000089
# [INFO] - Processing malawi-cyclone_00000245
# [INFO] - Processing malawi-cyclone_00000256
# [INFO] - Processing malawi-cyclone_00000035
# [INFO] - Processing malawi-cyclone_00000169
# [INFO] - Processing malawi-cyclone_00000124
# [INFO] - Processing malawi-cyclone_00000218
# [INFO] - Processing malawi-cyclone_00000291
# [INFO] - Processing malawi-cyclone_00000064
# [INFO] - Processing malawi-cyclone_00000309
# [INFO] - Processing malawi-cyclone_00000233
# [INFO] - Processing malawi-cyclone_00000148
# [INFO] - Processing malawi-cyclone_00000217
# [INFO] - Processing malawi-cyclone_00000000
# [INFO] - Processing malawi-cyclone_00000050
# [INFO] - Processing malawi-cyclone_00000012
# [INFO] - Processing malawi-cyclone_00000231
# [INFO] - Processing malawi-cyclone_00000039
# [INFO] - Processing malawi-cyclone_00000010
# [INFO] - Processing malawi-cyclone_00000336
# [INFO] - Processing malawi-cyclone_00000182
# [INFO] - Processing malawi-cyclone_00000165
# [INFO] - Processing malawi-cyclone_00000181
# [INFO] - Processing malawi-cyclone_00000127
# [INFO] - Processing malawi-cyclone_00000215
# [INFO] - Processing malawi-cyclone_00000278
# [INFO] - Processing malawi-cyclone_00000260
# [INFO] - Processing malawi-cyclone_00000154
# [INFO] - Processing malawi-cyclone_00000297
# [INFO] - Processing malawi-cyclone_00000344
# [INFO] - Processing malawi-cyclone_00000008
# [INFO] - Processing malawi-cyclone_00000326
# [INFO] - Processing malawi-cyclone_00000232
# [INFO] - Processing malawi-cyclone_00000075
# [INFO] - Processing malawi-cyclone_00000130
# [INFO] - Processing malawi-cyclone_00000277
# [INFO] - Processing malawi-cyclone_00000094
# [INFO] - Processing malawi-cyclone_00000044
# [INFO] - Processing malawi-cyclone_00000139
# [INFO] - Processing malawi-cyclone_00000015
# [INFO] - Processing malawi-cyclone_00000305
# [INFO] - Processing malawi-cyclone_00000308
# [INFO] - Processing malawi-cyclone_00000057
# [INFO] - Processing malawi-cyclone_00000253
# [INFO] - Processing malawi-cyclone_00000220
# [INFO] - Processing malawi-cyclone_00000147
# [INFO] - Processing malawi-cyclone_00000270
# [INFO] - Processing malawi-cyclone_00000289
# [INFO] - Processing malawi-cyclone_00000049
# [INFO] - Processing malawi-cyclone_00000066
# [INFO] - Processing malawi-cyclone_00000119
# [INFO] - Processing malawi-cyclone_00000164
# [INFO] - Processing malawi-cyclone_00000191
# [INFO] - Processing malawi-cyclone_00000171
# [INFO] - Processing malawi-cyclone_00000005
# [INFO] - Processing malawi-cyclone_00000029
# [INFO] - Processing malawi-cyclone_00000301
# [INFO] - Processing malawi-cyclone_00000262
# [INFO] - Processing malawi-cyclone_00000197
# [INFO] - Processing malawi-cyclone_00000273
# [INFO] - Processing malawi-cyclone_00000081
# [INFO] - Processing malawi-cyclone_00000131
# [INFO] - Processing malawi-cyclone_00000143
# [INFO] - Processing malawi-cyclone_00000242
# [INFO] - Processing malawi-cyclone_00000174
# [INFO] - Processing malawi-cyclone_00000295
# [INFO] - Processing malawi-cyclone_00000205
# [INFO] - Processing malawi-cyclone_00000102
# [INFO] - Processing malawi-cyclone_00000163
# [INFO] - Processing malawi-cyclone_00000187
# [INFO] - Processing malawi-cyclone_00000162
# [INFO] - Processing malawi-cyclone_00000097
# [INFO] - Processing malawi-cyclone_00000237
# [INFO] - Processing malawi-cyclone_00000106
# [INFO] - Processing malawi-cyclone_00000331
# [INFO] - Processing malawi-cyclone_00000045
# [INFO] - Processing malawi-cyclone_00000053
# [INFO] - Processing malawi-cyclone_00000288
# [INFO] - Processing malawi-cyclone_00000330
# [INFO] - Processing malawi-cyclone_00000093
# [INFO] - Processing malawi-cyclone_00000065
# [INFO] - Processing malawi-cyclone_00000267
# [INFO] - Processing malawi-cyclone_00000266
# [INFO] - Processing malawi-cyclone_00000312
# [INFO] - Processing malawi-cyclone_00000323
# [INFO] - Processing malawi-cyclone_00000021
# [INFO] - Processing malawi-cyclone_00000249
# [INFO] - Processing malawi-cyclone_00000146
# [INFO] - Processing malawi-cyclone_00000007
# [INFO] - Processing malawi-cyclone_00000132
# [INFO] - Processing malawi-cyclone_00000001
# [INFO] - Processing malawi-cyclone_00000121
# [INFO] - Processing malawi-cyclone_00000161
# [INFO] - Processing malawi-cyclone_00000333
# [INFO] - Processing malawi-cyclone_00000004
# [INFO] - Processing malawi-cyclone_00000152
# [INFO] - Processing malawi-cyclone_00000189
# [INFO] - Processing malawi-cyclone_00000274
# [INFO] - Processing malawi-cyclone_00000302
# [INFO] - Processing malawi-cyclone_00000112
# [INFO] - Processing malawi-cyclone_00000198
# [INFO] - Processing malawi-cyclone_00000133
# [INFO] - Processing malawi-cyclone_00000342
# [INFO] - Processing malawi-cyclone_00000280
# [INFO] - Processing malawi-cyclone_00000209
# [INFO] - Processing malawi-cyclone_00000276
# [INFO] - Processing malawi-cyclone_00000184
# [INFO] - Processing malawi-cyclone_00000300
# [INFO] - Processing malawi-cyclone_00000070
# [INFO] - Processing malawi-cyclone_00000014
# [INFO] - Processing malawi-cyclone_00000213
# [INFO] - Processing malawi-cyclone_00000293
# [INFO] - Processing malawi-cyclone_00000229
# [INFO] - Processing malawi-cyclone_00000207
# [INFO] - Processing malawi-cyclone_00000046
# [INFO] - Processing malawi-cyclone_00000225
# [INFO] - Processing malawi-cyclone_00000283
# [INFO] - Processing malawi-cyclone_00000315
# [INFO] - Processing malawi-cyclone_00000003
# [INFO] - Processing malawi-cyclone_00000221
# [INFO] - Processing malawi-cyclone_00000013
# [INFO] - Processing malawi-cyclone_00000114
# [INFO] - Processing malawi-cyclone_00000156
# [INFO] - Processing malawi-cyclone_00000265
# [INFO] - Processing malawi-cyclone_00000285
# [INFO] - Processing malawi-cyclone_00000275
# [INFO] - Processing malawi-cyclone_00000173
# [INFO] - Processing malawi-cyclone_00000040
# [INFO] - Processing malawi-cyclone_00000313
# [INFO] - Processing malawi-cyclone_00000134
# [INFO] - Processing malawi-cyclone_00000126
# [INFO] - Processing malawi-cyclone_00000236
# [INFO] - Processing malawi-cyclone_00000128
# [INFO] - Processing malawi-cyclone_00000170
# [INFO] - Processing malawi-cyclone_00000086
# [INFO] - Processing malawi-cyclone_00000338
# [INFO] - Processing malawi-cyclone_00000210
# [INFO] - Processing malawi-cyclone_00000299
# [INFO] - Processing malawi-cyclone_00000032
# [INFO] - Processing malawi-cyclone_00000074
# [INFO] - Processing malawi-cyclone_00000030
# [INFO] - Num destroyed 19
